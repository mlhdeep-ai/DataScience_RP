# %%
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.metrics import silhouette_score
import os

# %%
iris = pd.read_csv('../Datasets/iris.csv')
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class'], dtype='object')

# %%
x = iris.drop(['class'], axis = 1)
x
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# <h2>Method 1 - Elbow Curve Method</h2>

# %%
sum_of_squared_distances = []
k = range(2, 20)
for num_clusters in k:
    kmeans_model = KMeans(n_clusters = num_clusters)
    kmeans_model.fit(x)
    sum_of_squared_distances.append(kmeans_model.inertia_)

plt.figure(figsize = (15, 8))
plt.plot(k, sum_of_squared_distances, 'bx-')
plt.xlabel('Values of K')
plt.ylabel('Elbow Method for Optimal K')
plt.grid()
plt.show()

# %% [markdown]
# <h2>Method 2 - Silhouette Analysis</h2>

# %%
range_n_clusters = range(2, 20)
silhouette_avg = []
for k in range_n_clusters:
    kmeans_model = KMeans(n_clusters = k)
    kmeans_model.fit(x)
    cluster_labels = kmeans_model.labels_
    silhouette_avg.append(silhouette_score(x, cluster_labels))
    
plt.plot(range_n_clusters, silhouette_avg, 'bx-')
plt.xlabel('Value of K')
plt.ylabel('Silhouette score')
plt.title('Silhouette analysis for Optimal K')
plt.grid()

y1 = np.max(silhouette_avg)
x1 = range_n_clusters[np.argmax(silhouette_avg)]
txt = '(' + str(x1) + ',' + str(y1) + ')'
plt.text(x1, y1, txt)
plt.show()
